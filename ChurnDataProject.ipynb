# %%
# Import pandas library
import pandas as pd

# Read the CSV file
df = pd.read_csv('nimishchurn.csv')

# Display the first 5 rows of the dataframe
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df['TotalCharges']=df['TotalCharges'].replace(" ","0")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
print(df.shape)
print(df.head())
print(df.dtypes)
# Out:
# (7043, 21)
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
import matplotlib.pyplot as plt
gb = df.groupby('Churn').agg({'Churn':'count'})
plt.figure(figsize=(10,8))
plt.pie(gb['Churn'], labels=gb.index, autopct='%1.2f%%', startangle=90)
plt.axis('equal')
plt.show()

# %%
import seaborn as sns
ax = sns.countplot(x='gender', data=df, hue='Churn')
ax.bar_label(ax.containers)
ax.bar_label(ax.containers)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[50], line 3
#       1 import seaborn as sns
#       2 ax = sns.countplot(x='gender', data=df, hue='Churn')
# ----> 3 ax.bar_label(ax.containers)
#       4 ax.bar_label(ax.containers)
#       5 plt.show()
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/axes/_axes.py:2833, in Axes.bar_label(self, container, labels, fmt, label_type, padding, **kwargs)
#    2829     return 1 if x >= 0 else -1
#    2831 _api.check_in_list(['edge', 'center'], label_type=label_type)
# -> 2833 bars = container.patches
#    2834 errorbar = container.errorbar
#    2835 datavalues = container.datavalues
#
# AttributeError: 'list' object has no attribute 'patches'

# %%
import seaborn as sns
import matplotlib.pyplot as plt

ax = sns.countplot(x='gender', data=df, hue='Churn')

# Label each container individually
# containers[0] is the first group, containers[1] is the second group, etc.
for container in ax.containers:
    ax.bar_label(container)

plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.shape
# Out:
# (7043, 21)

# %%
plt.figure(figsize=(6, 6))
ax = sns.countplot(x='Contract', data=df, hue='Churn')
ax.bar_label(ax.containers[0])
ax.bar_label(ax.containers[1])
plt.show()

# %%
plt.figure(figsize=(10,10))
ax = sns.countplot(x='PaymentMethod',data=df, hue='Churn')
ax.bar_label(ax.containers[0])
ax.bar_label(ax.containers[1])
plt.show()

# %%
ax = sns.countplot(x='gender',data = df, hue='Churn')
ax.bar_label(ax.containers[0])
ax.bar_label(ax.containers[1])
plt.show()

# %%
ax = sns.countplot(x='PaperlessBilling',data = df, hue='Churn')
ax.bar_label(ax.containers[0])
ax.bar_label(ax.containers[1])
plt.show()

# %%
# Split customers into 4 groups
male_yes = df[(df['gender']=='Male') & (df['Churn']=='Yes')]
male_no = df[(df['gender']=='Male') & (df['Churn']=='No')]
female_yes = df[(df['gender']=='Female') & (df['Churn']=='Yes')]
female_no = df[(df['gender']=='Female') & (df['Churn']=='No')]

# Print segment sizes
print(f"Male Churned: {len(male_yes)}")
print(f"Male Retained: {len(male_no)}")
print(f"Female Churned: {len(female_yes)}")
print(f"Female Retained: {len(female_no)}")
# Out:
# Male Churned: 930
# Male Retained: 2625
# Female Churned: 939
# Female Retained: 2549

# %%
genders = ['Male', 'Female']
no_churn = [len(male_no), len(female_no)]
churn = [len(male_yes), len(female_yes)]

# Create stacked bar chart
fig, ax = plt.subplots(figsize=(8,6))
bars_no = ax.bar(genders, no_churn, color='#2c5282', label='No Churn')
bars_yes = ax.bar(genders, churn, bottom=no_churn, color='#c53030', label='Churned')

ax.bar_label(bars_no)
ax.bar_label(bars_yes)

# Styling
ax.set_title('Customer Retention by Gender')
ax.set_ylabel('Number of Customers')
ax.legend(title='Churn Status')
plt.tight_layout()
plt.show()

# %%
# Filter for churned customers only
churned_customers = df[df['Churn'] == 'Yes']

# Create tenure histogram
fig, ax = plt.subplots(figsize=(16, 10))
n, bins, patches = ax.hist(churned_customers['tenure'], 
                          bins=72, 
                          edgecolor='black', 
                          alpha=0.8)

for i, patch in enumerate(patches):
    if bins[i] <= 36:
        patch.set_color('red')
    else:
        patch.set_color('steelblue')

for i, count in enumerate(n):
    if count > 0:
        bin_center = (bins[i] + bins[i+1]) / 2
        ax.text(bin_center, count + 1, f'{int(count)}', 
               ha='center', va='bottom', fontweight='bold')

# Styling
ax.set_title('Customer Churn by Tenure\n(Red = High-Risk Period: 0-3 Years)')
ax.set_xlabel('Tenure (Months)')
ax.set_ylabel('Number of Churned Customers')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()

# Print summary statistics
total_churned = len(churned_customers)
early_churned = len(churned_customers[churned_customers['tenure'] <= 36])
print(f"\nTenure Analysis Summary:")
print(f"Total churned customers: {total_churned}")
print(f"Churned in first 3 years: {early_churned} ({early_churned/total_churned*100:.1f}%)")
# Out:
# Tenure Analysis Summary:
# Total churned customers: 1869
# Churned in first 3 years: 1511 (80.8%)
